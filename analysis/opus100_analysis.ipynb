# %% [markdown]
# # Translation analysis
#
# 1. what do deepchecks heuristics show me?
# 2. Are there text outlier detection methods that can be used?
# 3. Can i edit the text to make corpus better?

# %% [markdown]
# Datasets
#
# 1. Databricks dolly -- chatbot dataset
# 2. squad v2 -- validation set https://huggingface.co/datasets/squad_v2/viewer/squad_v2/validation
# 3. opus100-en-es-validation -- https://huggingface.co/datasets/opus100/viewer/en-es/validation
#
# Other (larger) 4. open-orca-100k -- from Lilac AI, their sample of 100k points out of 4.2M in total (https://huggingface.co/datasets/lilacai/lilac-OpenOrca-100k)

# %%
# import pandas as pd
# from datasets import load_dataset

# dataset = load_dataset("opus100", "en-es")
# l = dataset["validation"].to_list()
# d = [i["translation"] for i in l]

# df = pd.DataFrame(d)
# df.to_csv("../datasets/opus100-en-es.csv", index=False)

# %%
import pandas as pd

# %%
df = pd.read_csv("../datasets/opus100-en-es.csv")

# %%
df
# Out:
#                                                      en  \
# 0       I don't even remember what the fight was about.
# 1     Here are the sites of each of those that have ...
# 2                    I'm the man who killed Blackbeard.
# 3                                      Don't get smart.
# 4     Is there an exact moment in the life of a sold...
# ...                                                 ...
# 1995                [Scoffs] I believe the script says,
# 1996           You didn't even have a case against him.
# 1997                                    Ok. She's dead.
# 1998  Opinion of Advocate General Léger delivered on...
# 1999                               Prepare, yourselves.
#
#                                                      es
# 0                     No recuerdo por qué fue la pelea.
# 1     Estos son los sitios en que cada Congreso ha t...
# 2              Sí. Soy el hombre que mató a Barbanegra.
# 3                           No te hagas el inteligente.
# 4     ¿Existe un límite de cuándo se padece y cuándo...
# ...                                                 ...
# 1995                       Me parece que el guión dice:
# 1996           Ni siquiera tenían un caso en su contra.
# 1997                            Como lo desees, cariño.
# 1998  Conclusiones del Abogado General Sr. P. Léger,...
# 1999                                        Preparense.
#
# [2000 rows x 2 columns]

# %%
from deepchecks.nlp import TextData

# %%
deepcheckObj = TextData(df["es"], label=df["en"], task_type="text_classification")
#  metadata=train.drop(columns=['label', 'text']))

# %%
# properties can be either calculated directly by Deepchecks
# or imported from other sources in appropriate format

props = deepcheckObj.calculate_builtin_properties(
    include_long_calculation_properties=False
)
# Out:
# 100%|██████████| 125/125 [00:00<00:00, 176.94it/s]

# %%
deepcheckObj.properties.columns
# Out:
# Index(['Text Length', 'Average Word Length', 'Max Word Length',
#        '% Special Characters', '% Punctuation', 'Language', 'Sentiment',
#        'Subjectivity', 'Average Words Per Sentence', 'Reading Ease',
#        'Lexical Density'],
#       dtype='object')

# %%
from deepchecks.nlp.suites import data_integrity

data_integrity_suite = data_integrity()
result = data_integrity_suite.run(deepcheckObj)
result
# Out:
#     <style>
#         progress {
#             -webkit-appearance: none;
#             border: none;
#             border-radius: 3px;
#             width: 300px;
#             height: 20px;
#             vertical-align: middle;
#             margin-right: 10px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-bar {
#             border-radius: 3px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-value {
#             background-color: #9d60fb;
#         }
#         progress::-moz-progress-bar {
#             background-color: #9d60fb;
#         }
#     </style>
# /Users/wepperso/miniconda3/envs/text-py-3.9/lib/python3.9/site-packages/deepchecks/nlp/utils/weak_segments.py:59: UserWarning:
#
# Parameter n_top_properties is set to 10 to avoid long computation time. This means that the check will run on 10 properties selected at random. If you want to run on all properties, set n_top_properties to None. Alternatively, you can set parameter properties to a list of the specific properties you want to run on.
# Accordion(children=(VBox(children=(HTML(value='\n<h1 id="summary_J0EENKMYCM7I61JCIR9VFPPYH">Data Integrity Sui…

# %%
r = result.to_json()
print(r)
# Out:
# {"name": "Data Integrity Suite", "results": [{"type": "CheckResult", "check": {"name": "Text Property Outliers", "params": {"n_show_top": 5, "iqr_percentiles": [25, 75], "iqr_scale": 2, "sharp_drop_ratio": 0.9, "min_samples": 10}, "summary": "Find outliers with respect to the given properties. <a href=\"https://docs.deepchecks.com/0.17/nlp/auto_checks/data_integrity/plot_text_property_outliers.html?utm_source=display_output&utm_medium=referral&utm_campaign=check_link\" target=\"_blank\">Read More...</a>"}, "header": "Text Property Outliers", "value": {"Text Length": {"indices": [{"dtype": "int64", "value": 1136}, {"dtype": "int64", "value": 954}, {"dtype": "int64", "value": 174}, {"dtype": "int64", "value": 526}, {"dtype": "int64", "value": 1974}, {"dtype": "int64", "value": 916}, {"dtype": "int64", "value": 700}, {"dtype": "int64", "value": 1797}, {"dtype": "int64", "value": 281}, {"dtype": "int64", "value": 902}, {"dtype": "int64", "value": 125}, {"dtype": "int64", "value": 933}, {"dtype": "int64", "value": 295}, {"dtype": "int64", "value": 1628}, {"dtype": "int64", "value": 178}, {"dtype": "int64", "value": 1768}, {"dtype": "int64", "value": 662}, {"dtype": "int64", "value": 462}, {"dtype": "int64", "value": 1924}, {"dtype": "int64", "value": 1403}, {"dtype": "int64", "value": 637}, {"dtype": "int64", "value": 1536}, {"dtype": "int64", "value": 591}, {"dtype": "int64", "value": 652}, {"dtype": "int64", "value": 1529}, {"dtype": "int64", "value": 887}, {"dtype": "int64", "value": 48}, {"dtype": "int64", "value": 1233}, {"dtype": "int64", "value": 792}, {"dtype": "int64", "value": 573}, {"dtype": "int64", "value": 1316}, {"dtype": "int64", "value": 1015}, {"dtype": "int64", "value": 1260}, {"dtype": "int64", "value": 1499}, {"dtype": "int64", "value": 1738}, {"dtype": "int64", "value": 1201}, {"dtype": "int64", "value": 616}, {"dtype": "int64", "value": 1045}, {"dtype": "int64", "value": 129}, {"dtype": "int64", "value": 1389}, {"dtype": "int64", "value": 1530}, {"dtype": "int64", "value": 749}, {"dtype": "int64", "value": 733}, {"dtype": "int64", "value": 1595}, {"dtype": "int64", "value": 12}, {"dtype": "int64", "value": 819}, {"dtype": "int64", "value": 1123}, {"dtype": "int64", "value": 1452}, {"dtype": "int64", "value": 1289}, {"dtype": "int64", "value": 760}, {"dtype": "int64", "value": 146}, {"dtype": "int64", "value": 201}, {"dtype": "int64", "value": 183}, {"dtype": "int64", "value": 1183}, {"dtype": "int64", "value": 998}, {"dtype": "int64", "value": 287}, {"dtype": "int64", "value": 1561}, {"dtype": "int64", "value": 782}, {"dtype": "int64", "value": 116}, {"dtype": "int64", "value": 1086}, {"dtype": "int64", "value": 133}, {"dtype": "int64", "value": 1275}, {"dtype": "int64", "value": 1925}, {"dtype": "int64", "value": 172}, {"dtype": "int64", "value": 548}, {"dtype": "int64", "value": 1814}, {"dtype": "int64", "value": 495}, {"dtype": "int64", "value": 1380}, {"dtype": "int64", "value": 1778}, {"dtype": "int64", "value": 1713}, {"dtype": "int64", "value": 1348}, {"dtype": "int64", "value": 720}, {"dtype": "int64", "value": 512}, {"dtype": "int64", "value": 1156}, {"dtype": "int64", "value": 1846}, {"dtype": "int64", "value": 1854}, {"dtype": "int64", "value": 1166}, {"dtype": "int64", "value": 1562}, {"dtype": "int64", "value": 1801}, {"dtype": "int64", "value": 1344}, {"dtype": "int64", "value": 1950}, {"dtype": "int64", "value": 29}, {"dtype": "int64", "value": 227}, {"dtype": "int64", "value": 1875}, {"dtype": "int64", "value": 1304}, {"dtype": "int64", "value": 1355}, {"dtype": "int64", "value": 1644}, {"dtype": "int64", "value": 532}, {"dtype": "int64", "value": 418}, {"dtype": "int64", "value": 1215}, {"dtype": "int64", "value": 657}, {"dtype": "int64", "value": 1077}, {"dtype": "int64", "value": 1888}, {"dtype": "int64", "value": 797}, {"dtype": "int64", "value": 1850}, {"dtype": "int64", "value": 844}, {"dtype": "int64", "value": 1515}, {"dtype": "int64", "value": 1684}, {"dtype": "int64", "value": 100},  ...

# %%
df["en"].str.split()
# Out:
# 0         I don't even remember what the fight was about.
# 1       Here are the sites of each of those that have ...
# 2                      I'm the man who killed Blackbeard.
# 3                                        Don't get smart.
# 4       Is there an exact moment in the life of a sold...
#                               ...
# 1995                  [Scoffs] I believe the script says,
# 1996             You didn't even have a case against him.
# 1997                                      Ok. She's dead.
# 1998    Opinion of Advocate General Léger delivered on...
# 1999                                 Prepare, yourselves.
# Name: en, Length: 2000, dtype: object

# %%
df["en"].str.split().str.len()
# Out:
# 0        9
# 1       12
# 2        6
# 3        3
# 4       24
#         ..
# 1995     6
# 1996     8
# 1997     3
# 1998    11
# 1999     2
# Name: en, Length: 2000, dtype: int64

# %%
import string


def is_string_series(s: pd.Series):
    if isinstance(s.dtype, pd.StringDtype):
        # The series was explicitly created as a string series (Pandas>=1.0.0)
        return True
    elif s.dtype == "object":
        # Object series, check each value
        return all((v is None) or isinstance(v, str) for v in s)
    else:
        return False


def extract_all_metadata(df: pd.DataFrame):
    for colname in df.columns:
        if is_string_series(df[colname]):
            metadata = extract_column_metadata(df[colname])
            df = df.join(metadata)

    return df


def get_special_char_percentage(s: str):
    special_chars = set(string.punctuation)
    num_special_chars = sum(1 for c in s if c in special_chars)
    return num_special_chars / len(s)


def get_word_data(s: str):
    # other potential metadata: 'Language', 'Sentiment', 'Subjectivity', 'Reading Ease', 'Lexical Density'

    split_arr = s.split()
    return pd.Series(
        {
            "text_length": len(s),
            "num_words": len(split_arr),
            "max_word_length": max([len(w) for w in split_arr]),
            "avg_word_length": sum([len(w) for w in split_arr]) / len(s.split()),
            "perc_special_chars": get_special_char_percentage(s),
        }
    )


def extract_column_metadata(col: pd.Series):
    col_name = col.name
    m = col.apply(get_word_data)
    m = m.rename(columns={c: f"{col_name}_{c}" for c in m.columns})

    return m

# %%
extract_all_metadata(df)
# Out:
#                                                      en  \
# 0       I don't even remember what the fight was about.
# 1     Here are the sites of each of those that have ...
# 2                    I'm the man who killed Blackbeard.
# 3                                      Don't get smart.
# 4     Is there an exact moment in the life of a sold...
# ...                                                 ...
# 1995                [Scoffs] I believe the script says,
# 1996           You didn't even have a case against him.
# 1997                                    Ok. She's dead.
# 1998  Opinion of Advocate General Léger delivered on...
# 1999                               Prepare, yourselves.
#
#                                                      es  en_text_length  \
# 0                     No recuerdo por qué fue la pelea.            47.0
# 1     Estos son los sitios en que cada Congreso ha t...            58.0
# 2              Sí. Soy el hombre que mató a Barbanegra.            34.0
# 3                           No te hagas el inteligente.            16.0
# 4     ¿Existe un límite de cuándo se padece y cuándo...           122.0
# ...                                                 ...             ...
# 1995                       Me parece que el guión dice:            35.0
# 1996           Ni siquiera tenían un caso en su contra.            40.0
# 1997                            Como lo desees, cariño.            15.0
# 1998  Conclusiones del Abogado General Sr. P. Léger,...            66.0
# 1999                                        Preparense.            20.0
#
#       en_num_words  en_max_word_length  en_avg_word_length  \
# 0              9.0                 8.0            4.333333
# 1             12.0                 6.0            3.916667
# 2              6.0                11.0            4.833333
# 3              3.0                 6.0            4.666667
# 4             24.0                11.0            4.125000
# ...            ...                 ...                 ...
# 1995           6.0                 8.0            5.000000
# 1996           8.0                 7.0            4.125000
# 1997           3.0                 5.0            4.333333
# 1998          11.0                 9.0            5.090909
# 1999           2.0                11.0            9.500000
#
#       en_perc_special_chars  es_text_length  es_num_words  es_max_word_length  \
# 0                  0.042553            33.0           7.0                 8.0
# 1                  0.017241            58.0          11.0                 8.0
# 2                  0.058824            40.0           8.0                11.0
# 3                  0.125000            27.0           5.0                12.0
# 4                  0.016393            50.0          10.0                 7.0
# ...                     ...             ...           ...                 ...
# 1995               0.085714            28.0           6.0                 6.0
# 1996               0.050000            40.0           8.0                 8.0
# 1997               0.200000            23.0           4.0                 7.0
# 1998               0.045455            81.0          14.0                12.0
# 1999               0.100000            11.0           1.0                11.0
#
#       es_avg_word_length  es_perc_special_chars
# 0               3.857143               0.030303
# 1               4.363636               0.017241
# 2               4.125000               0.050000
# 3               4.600000               0.037037
# 4               4.100000               0.020000
# ...                  ...                    ...
# 1995            3.833333               0.035714
# 1996            4.125000               0.025000
# 1997            5.000000               0.086957
# 1998            4.857143               0.037037
# 1999           11.000000               0.090909
#
# [2000 rows x 12 columns]
