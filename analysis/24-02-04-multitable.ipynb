# %%
import pandas as pd

# %%
# from textprofilerbackend.transform import get_word_tokens_batch, get_byte_encoding_batch
# from textprofilerbackend.textclean import get_textcol_metadata_embeddings

# %%
vis_papers = pd.read_parquet(
    "../datasets/local/vis_papers/processed/vis_papers.parquet"
)

# %%
from nltk.tokenize import TreebankWordTokenizer as twt
from concurrent.futures import ThreadPoolExecutor


tokenizer = twt()


def get_words_w_span(text):
    token_idx = tokenizer.span_tokenize(text)
    _df = pd.DataFrame(token_idx, columns=["span_start", "span_end"])
    _df["word"] = _df.apply(lambda x: text[x.span_start : x.span_end], axis=1)

    return _df


def get_words_w_span_batch(arr: list[str], num_threads=8) -> list[list[str]]:
    """Split array of strings into word tokens using nltk.
    Returns: 2d array of strings"""
    with ThreadPoolExecutor(num_threads) as executor:
        return list(executor.map(get_words_w_span, arr))

# %%
abstracts = vis_papers["Abstract"]
abstracts_non_null = abstracts.dropna().reset_index(drop=True)

# %%
get_words_w_span(abstracts_non_null.iloc[0])
# Out:
#      span_start  span_end             word
# 0             0        13    Accessibility
# 1            14        24       guidelines
# 2            25        30            place
# 3            31        43     restrictions
# 4            44        46               on
# ..          ...       ...              ...
# 297        2084      2086               at
# 298        2087      2092            https
# 299        2092      2093                :
# 300        2093      2108  //osf.io/8kzmg/
# 301        2108      2109                .
#
# [302 rows x 3 columns]

# %%
r = get_words_w_span_batch(abstracts_non_null)

# %%
# r is your list of dataframes
for i, _mydf in enumerate(r):
    _mydf["id"] = i

# %%
all_results = pd.concat(r, ignore_index=True)

# %%
all_results.to_parquet(
    "../datasets/local/vis_papers/processed/vis_papers_words_span.parquet"
)

# %%
pd.concat(r, ignore_index=True)
# Out:
#         span_start  span_end           word    id
# 0                0        13  Accessibility     0
# 1               14        24     guidelines     0
# 2               25        30          place     0
# 3               31        43   restrictions     0
# 4               44        46             on     0
# ...            ...       ...            ...   ...
# 613515         942       944             gt  3548
# 613516         944       945              ;  3548
# 613517         945       946              &  3548
# 613518         946       948             gt  3548
# 613519         948       949              ;  3548
#
# [613520 rows x 4 columns]

# %%
vis_papers_w_ab = vis_papers[vis_papers["Abstract"].notnull()]

# %%
vis_papers_w_ab.columns
# Out:
# Index(['id', 'Conference', 'Year', 'Title', 'DOI', 'Link', 'FirstPage',
#        'LastPage', 'PaperType', 'Abstract', 'AuthorNames-Deduped',
#        'AuthorNames', 'AuthorAffiliation', 'InternalReferences',
#        'AuthorKeywords', 'AminerCitationCount', 'CitationCount_CrossRef',
#        'PubsCited_CrossRef', 'Award', 'Abstract_text_length',
#        'Abstract_num_words', 'Abstract_max_word_length',
#        'Abstract_avg_word_length', 'Abstract_perc_special_chars'],
#       dtype='object')

# %%
df = vis_papers_w_ab[["Abstract", "AuthorNames-Deduped", "AuthorKeywords"]]

# %%
df
# Out:
#                                                Abstract  \
# 0     Accessibility guidelines place restrictions on...
# 1     Horizontal federated learning (HFL) enables di...
# 2     We present Rigel, an interactive system for ra...
# 3     We developed and validated a rating scale to a...
# 4     The success of DL can be attributed to hours o...
# ...                                                 ...
# 3544  The author applied image processing and volume...
# 3545  The problem of presenting and gaining deeper u...
# 3546  A hierarchical triangulation built from a digi...
# 3547  A methodology for guiding the choice of visual...
# 3548  The author describes a visualization model for...
#
#                                     AuthorNames-Deduped  \
# 0                           Laura South;Michelle Borkin
# 1     Xumeng Wang;Wei Chen 0001;Jiazhi Xia;Zhen Wen;...
# 2     Ran Chen;Di Weng;Yanwei Huang;Xinhuan Shu;Jiay...
# 3     Tingying He;Petra Isenberg;Raimund Dachselt;To...
# 4               Anjul Tyagi;Cong Xie;Klaus Mueller 0001
# ...                                                 ...
# 3544                                   Nahum D. Gershon
# 3545                 Wayne E. Fordyce;Jeffrey Ventrella
# 3546              Lori L. Scarlatos;Theodosios Pavlidis
# 3547                                Philip K. Robertson
# 3548                                    Wolfgang Krüger
#
#                                          AuthorKeywords
# 0     accessibility,photosensitive epilepsy,photosen...
# 1     Federated learning,data heterogeneity,cluster ...
# 2     Data transformation,self-service data transfor...
# 3     Aesthetics,aesthetic pleasure,validated scale,...
# 4     Deep Learning,Neural Network Architecture Sear...
# ...                                                 ...
# 3544                                               None
# 3545                                               None
# 3546                                               None
# 3547                                               None
# 3548                                               None
#
# [3549 rows x 3 columns]

# %%
def parseCol(item):
    if not item:
        return None

    l = item.split(";")
    idxs = []
    curr = 0
    for item in l:
        idxs.append((curr, curr + len(item)))
        curr += len(item) + 1

    _df = pd.DataFrame(idxs, columns=["span_start", "span_end"])
    _df["item"] = l

    return _df


def parseCol2(item):
    if not item:
        return None

    l = item.split(",")
    idxs = []
    curr = 0
    for item in l:
        idxs.append((curr, curr + len(item)))
        curr += len(item) + 1

    _df = pd.DataFrame(idxs, columns=["span_start", "span_end"])
    _df["item"] = l

    return _df

# %%
r = df["AuthorNames-Deduped"].apply(parseCol)

# %%
def apply_batch(arr, func, num_threads=8):
    with ThreadPoolExecutor(num_threads) as executor:
        return list(executor.map(func, arr))

# %%
r = apply_batch(df["AuthorNames-Deduped"], parseCol)

# %%
for i, _mydf in enumerate(r):
    if _mydf is not None:
        _mydf["id"] = i

# %%
authors = pd.concat(r, ignore_index=True)

# %%
df[df["AuthorKeywords"].isna()]
# Out:
#                                                Abstract  \
# 163   In theory, efficient and high-quality renderin...
# 311   In the last two decades, interactive visualiza...
# 367   Existing interactive visualization tools for d...
# 730   Textual criticism consists of the identificati...
# 741   Subspace analysis methods have gained interest...
# ...                                                 ...
# 3544  The author applied image processing and volume...
# 3545  The problem of presenting and gaining deeper u...
# 3546  A hierarchical triangulation built from a digi...
# 3547  A methodology for guiding the choice of visual...
# 3548  The author describes a visualization model for...
#
#                                     AuthorNames-Deduped AuthorKeywords
# 163           Ingo Wald;Nathan Morrical;Stefan Zellmann           None
# 311                   Leilani Battle;Carlos Scheidegger           None
# 367   Xinyi Huang;Suphanut Jamonnak;Ye Zhao 0003;Boy...           None
# 730                 Stefan Jänicke;David Joseph Wrisley           None
# 741   Dominik Jäckle;Michael Blumenschein;Michael Be...           None
# ...                                                 ...            ...
# 3544                                   Nahum D. Gershon           None
# 3545                 Wayne E. Fordyce;Jeffrey Ventrella           None
# 3546              Lori L. Scarlatos;Theodosios Pavlidis           None
# 3547                                Philip K. Robertson           None
# 3548                                    Wolfgang Krüger           None
#
# [917 rows x 3 columns]

# %%
authors.to_parquet(
    "../datasets/local/vis_papers/processed/vis_papers_authors_span.parquet"
)

# %%
r2 = apply_batch(df["AuthorKeywords"], parseCol2)

# %%
for i, _mydf in enumerate(r2):
    if _mydf is not None:
        _mydf["id"] = i

# %%
keywords = pd.concat(r2, ignore_index=True)

# %%
keywords.to_parquet(
    "../datasets/local/vis_papers/processed/w_span/vis_papers_keywords_span.parquet"
)

# %%
keywords
# Out:
#        span_start  span_end                                     item    id
# 0               0        13                            accessibility     0
# 1              14        37                  photosensitive epilepsy     0
# 2              38        54                         photosensitivity     0
# 3              55        66                              interaction     0
# 4              67        85                       data visualization     0
# ...           ...       ...                                      ...   ...
# 11818           0        23                  Grammar-directed design  3462
# 11819          24        56          cooperative design and modeling  3462
# 11820          57        75                        design automation  3462
# 11821          76       103               human-computer interaction  3462
# 11822         104       143   automated design of graphical displays  3462
#
# [11823 rows x 4 columns]
